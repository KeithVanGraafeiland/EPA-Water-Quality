# %%
arcpy.management.Append(
    inputs=r"C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv",
    target="blank_table",
    schema_type="NO_TEST",
    field_mapping=r'OrganizationIdentifier "Organization Identifier" true true false 35 Text 0 0,First,#,'new_file',OrganizationIdentifier,0,8000;OrganizationFormalName "Organization Formal Name" true true false 35 Text 0 0,First,#,'new_file',OrganizationFormalName,0,8000;ActivityIdentifier "Activity Identifier" true true false 55 Text 0 0,First,#,'new_file',ActivityIdentifier,0,8000;ActivityStartDate "Activity Start Date" true true false 8 Date 0 0,First,#,'new_file',ActivityStartDate,-1,-1;ActivityStartTime "Activity Start Time" true true false 8 Date 0 0,First,#,'new_file',ActivityStartTime/Time,0,8000;ActivityStartTimeZoneCode "Activity Start Time Zone Code" true true false 4 Text 0 0,First,#,'new_file',ActivityStartTime/TimeZoneCode,0,8000;MonitoringLocationIdentifier "Monitoring Location Identifier" true true false 55 Text 0 0,First,#,'new_file',MonitoringLocationIdentifier,0,8000;ResultIdentifier "Result Identifier" true true false 35 Text 0 0,First,#,'new_file',ResultIdentifier,0,8000;DataLoggerLine "Data Logger Line Name" true true false 60 Text 0 0,First,#,'new_file',DataLoggerLine,0,8000;ResultDetectionConditionText "Result Detection Condition Text" true true false 40 Text 0 0,First,#,'new_file',ResultDetectionConditionText,0,8000;MethodSpecificationName "Method Specification Name" true true false 20 Text 0 0,First,#,'new_file',MethodSpecificationName,0,8000;CharacteristicName "Characteristic Name" true true false 255 Text 0 0,First,#,'new_file',CharacteristicName,0,8000;ResultSampleFractionText "Result Sample Fraction Text" true true false 25 Text 0 0,First,#,'new_file',ResultSampleFractionText,0,8000;ResultMeasureValue "Result Measure Value" true true false 60 Text 0 0,First,#,'new_file',ResultMeasureValue,-1,-1;ResultMeasureUnitCode "Result Measure/Measure Unit Code" true true false 25 Text 0 0,First,#,'new_file',ResultMeasure/MeasureUnitCode,0,8000;MeasureQualifierCode "Measure Qualifier Code" true true false 35 Text 0 0,First,#,'new_file',MeasureQualifierCode,0,8000;ResultStatusIdentifier "Result Status Identifier" true true false 12 Text 0 0,First,#,'new_file',ResultStatusIdentifier,0,8000;StatisticalBaseCode "Statistical Base Code" true true false 25 Text 0 0,First,#,'new_file',StatisticalBaseCode,0,8000;ResultValueTypeName "Result Value Type Name" true true false 20 Text 0 0,First,#,'new_file',ResultValueTypeName,0,8000;ResultWeightBasisText "Result Weight Basis Text" true true false 20 Text 0 0,First,#,'new_file',ResultWeightBasisText,0,8000;ResultTimeBasisText "Result Time Basis Text" true true false 12 Text 0 0,First,#,'new_file',ResultTimeBasisText,0,8000;ResultTemperatureBasisText "Result Temperature Basis Text" true true false 12 Text 0 0,First,#,'new_file',ResultTemperatureBasisText,0,8000;ResultParticleSizeBasisText "Result Particle Size Basis Text" true true false 40 Text 0 0,First,#,'new_file',ResultParticleSizeBasisText,0,8000;PrecisionValue "Precision Value" true true false 60 Text 0 0,First,#,'new_file',PrecisionValue,0,8000;BiasValue "DataQuality/BiasValue" true true false 60 Text 0 0,First,#,'new_file',DataQuality/BiasValue,0,8000;ConfidenceIntervalValue "Confidence Interval Value" true true false 60 Text 0 0,First,#,'new_file',ConfidenceIntervalValue,0,8000;UpperConfidenceLimitValue "Upper Confidence Limit Value" true true false 60 Text 0 0,First,#,'new_file',UpperConfidenceLimitValue,0,8000;LowerConfidenceLimitValue "Lower Confidence Limit Value" true true false 60 Text 0 0,First,#,'new_file',LowerConfidenceLimitValue,0,8000;ResultCommentText "Result Comment Text" true true false 4000 Text 0 0,First,#,'new_file',ResultCommentText,0,8000;USGSPCode "USGSP Code" true true false 25 Text 0 0,First,#,'new_file',USGSPCode,-1,-1;ResultDepthHeightMeasureValue "Result Depth Height Measure/Measure Value" true true false 60 Text 0 0,First,#,'new_file',ResultDepthHeightMeasure/MeasureValue,0,8000;ResultDepthHeightMeasureUnitCode "Result Depth Height Measure/Measure Unit Code" true true false 12 Text 0 0,First,#,'new_file',ResultDepthHeightMeasure/MeasureUnitCode,0,8000;ResultDepthAltitudeReferencePointText "Result Depth Altitude Reference Point Text" true true false 125 Text 0 0,First,#,'new_file',ResultDepthAltitudeReferencePointText,0,8000;ResultSamplingPointName "Result Sampling Point Name" true true false 120 Text 0 0,First,#,'new_file',ResultSamplingPointName,0,8000;BiologicalIntentName "Biological Intent Name" true true false 35 Text 0 0,First,#,'new_file',BiologicalIntentName,0,8000;BiologicalIndividualIdentifier "Biological Individual Identifier" true true false 60 Text 0 0,First,#,'new_file',BiologicalIndividualIdentifier,0,8000;SubjectTaxonomicName "Subject Taxonomic Name" true true false 255 Text 0 0,First,#,'new_file',SubjectTaxonomicName,0,8000;UnidentifiedSpeciesIdentifier "Unidentified Species Identifier" true true false 255 Text 0 0,First,#,'new_file',UnidentifiedSpeciesIdentifier,0,8000;SampleTissueAnatomyName "Sample Tissue Anatomy Name" true true false 50 Text 0 0,First,#,'new_file',SampleTissueAnatomyName,0,8000;GroupSummaryCountMeasureValue "Group Summary Count Weight/Measure Value" true true false 60 Text 0 0,First,#,'new_file',GroupSummaryCountWeight/MeasureValue,0,8000;GroupSummaryCountWeightMeasureUnitCode "Group Summary Count Weight/Measure Unit Code" true true false 12 Text 0 0,First,#;CellFormName "Cell Form Name" true true false 11 Text 0 0,First,#,'new_file',CellFormName,0,8000;CellShapeName "Cell Shape Name" true true false 18 Text 0 0,First,#,'new_file',CellShapeName,0,8000;HabitName "Habit Name" true true false 14 Text 0 0,First,#,'new_file',HabitName,0,8000;VoltismName "Voltism Name" true true false 30 Text 0 0,First,#,'new_file',VoltismName,0,8000;TaxonomicPollutionTolerance "Taxonomic Pollution Tolerance" true true false 30 Text 0 0,First,#,'new_file',TaxonomicPollutionTolerance,0,8000;TaxonomicPollutionToleranceScaleText "Taxonomic Pollution Tolerance Scale Text" true true false 50 Text 0 0,First,#,'new_file',TaxonomicPollutionToleranceScaleText,0,8000;TrophicLevelName "Trophic Level Name" true true false 30 Text 0 0,First,#,'new_file',TrophicLevelName,0,8000;FunctionalFeedingGroupName "Functional Feeding Group Name" true true false 30 Text 0 0,First,#,'new_file',FunctionalFeedingGroupName,0,8000;ResourceTitleName "Taxonomic Details Citation/Resource Title Name" true true false 120 Text 0 0,First,#,'new_file',TaxonomicDetailsCitation/ResourceTitleName,0,8000;ResourceCreatorName "Taxonomic Details Citation/Resource Creator Name" true true false 120 Text 0 0,First,#,'new_file',TaxonomicDetailsCitation/ResourceCreatorName,0,8000;ResourceSubjectText "Taxonomic Details Citation/Resource Subject Text" true true false 4000 Text 0 0,First,#,'new_file',TaxonomicDetailsCitation/ResourceSubjectText,0,8000;ResourcePublisherName "Taxonomic Details Citation/Resource Publisher Name" true true false 60 Text 0 0,First,#,'new_file',TaxonomicDetailsCitation/ResourcePublisherName,0,8000;ResourceDate "Taxonomic Details Citation/Resource Date" true true false 8 Date 0 0,First,#,'new_file',TaxonomicDetailsCitation/ResourceDate,0,8000;ResourceIdentifier "Taxonomic Details Citation/Resource Identifier" true true false 255 Text 0 0,First,#,'new_file',TaxonomicDetailsCitation/ResourceIdentifier,0,8000;FrequencyClassInformationUrl "Frequency Class Information Url" true true false 255 Text 0 0,First,#,'new_file',FrequencyClassInformationUrl,0,8000;MethodIdentifier "Result Analytical Method/Method Identifier" true true false 35 Text 0 0,First,#,'new_file',ResultAnalyticalMethod/MethodIdentifier,0,8000;MethodIdentifierContext "Result Analytical Method/Method Identifier Context" true true false 120 Text 0 0,First,#,'new_file',ResultAnalyticalMethod/MethodIdentifierContext,0,8000;MethodName "Result Analytical Method/Method Name" true true false 250 Text 0 0,First,#,'new_file',ResultAnalyticalMethod/MethodName,0,8000;MethodUrl "Result Analytical Method/Method Url" true true false 255 Text 0 0,First,#,'new_file',ResultAnalyticalMethod/MethodUrl,0,8000;MethodQualifierTypeName "Result Analytical Method/Method Qualifier Type Name" true true false 25 Text 0 0,First,#,'new_file',ResultAnalyticalMethod/MethodQualifierTypeName,0,8000;MethodDescriptionText "Method Description Text" true true false 4000 Text 0 0,First,#,'new_file',MethodDescriptionText,0,8000;LaboratoryName "Laboratory Name" true true false 60 Text 0 0,First,#,'new_file',LaboratoryName,0,8000;AnalysisStartDate "Analysis Start Date" true true false 8 Date 0 0,First,#,'new_file',AnalysisStartDate,0,8000;AnalysisStartTime "Analysis Start Time" true true false 8 Date 0 0,First,#,'new_file',AnalysisStartTime/Time,0,8000;AnalysisStartTimeZoneCode "Analysis Start Time Zone Code" true true false 4 Text 0 0,First,#,'new_file',AnalysisStartTime/TimeZoneCode,0,8000;AnalysisEndDate "Analysis End Date" true true false 8 Date 0 0,First,#,'new_file',AnalysisEndDate,0,8000;AnalysisEndTime "Analysis End Time" true true false 8 Date 0 0,First,#,'new_file',AnalysisEndTime/Time,0,8000;AnalysisEndTimeZoneCode "Analysis End Time Zone Code" true true false 4 Text 0 0,First,#,'new_file',AnalysisEndTime/TimeZoneCode,0,8000;ResultLaboratoryCommentCode "Result Laboratory Comment Code" true true false 120 Text 0 0,First,#,'new_file',ResultLaboratoryCommentCode,0,8000;ResultLaboratoryCommentText "Result Laboratory Comment Text" true true false 4000 Text 0 0,First,#,'new_file',ResultLaboratoryCommentText,0,8000;ResultDetectionQuantitationLimitUrl "Result Detection Quantitation Limit Url" true true false 255 Text 0 0,First,#,'new_file',ResultDetectionQuantitationLimitUrl,0,8000;LaboratoryAccreditationIndicator "Laboratory Accreditation Indicator" true true false 2 Short 0 0,First,#,'new_file',LaboratoryAccreditationIndicator,0,8000;LaboratoryAccreditationAuthorityName "Laboratory Accreditation Authority Name" true true false 20 Text 0 0,First,#,'new_file',LaboratoryAccreditationAuthorityName,0,8000;TaxonomistAccreditationIndicator "Taxonomist Accreditation Indicator" true true false 2 Short 0 0,First,#,'new_file',TaxonomistAccreditationIndicator,0,8000;TaxonomistAccreditationAuthorityName "Taxonomist Accreditation Authority Name" true true false 20 Text 0 0,First,#,'new_file',TaxonomistAccreditationAuthorityName,0,8000;LabSamplePreparationUrl "Lab Sample Preparation Url" true true false 255 Text 0 0,First,#,'new_file',LabSamplePreparationUrl,0,8000;ProviderName "Provider Name" true true false 30 Text 0 0,First,#,'new_file',ProviderName,0,8000;MonitoringLocationName "Monitoring Location Name" true true false 255 Text 0 0,First,#,'new_file',MonitoringLocationName,0,8000;MonitoringLocationTypeName "Monitoring Location Type Name" true true false 45 Text 0 0,First,#,'new_file',MonitoringLocationTypeName,0,8000;ResolvedMonitoringLocationTypeName "Resolved Monitoring Location Type Name" true true false 50 Text 0 0,First,#,'new_file',ResolvedMonitoringLocationTypeName,0,8000;HUCEightDigitCode "HUC Eight Digit Code" true true false 8 Text 0 0,First,#,'new_file',HUCEightDigitCode,-1,-1;siteUrl "site Url" true true false 255 Text 0 0,First,#,'new_file',siteUrl,0,8000;ActivityCount "Activity Count" true true false 2 Short 0 0,First,#,'new_file',activityCount,-1,-1;ResultCount "Result Count" true true false 2 Short 0 0,First,#,'new_file',resultCount,-1,-1;StateName "State Name" true true false 55 Text 0 0,First,#,'new_file',StateName,0,8000;CountyName "County Name" true true false 55 Text 0 0,First,#,'new_file',CountyName,0,8000',
    subtype="",
    expression="",
    match_fields=None,
    update_geometry="NOT_UPDATE_GEOMETRY"
)

# %%
arcpy.management.Append(
    inputs=r"C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv",
    target="GoMA_Sample_Data",
    schema_type="NO_TEST",
    field_mapping=r'OrganizationIdentifier "OrganizationIdentifier" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,OrganizationIdentifier,0,8000;OrganizationFormalName "OrganizationFormalName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,OrganizationFormalName,0,8000;ActivityIdentifier "ActivityIdentifier" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ActivityIdentifier,0,8000;ActivityStartDate "ActivityStartDate" true true false 8 Date 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ActivityStartDate,-1,-1;ActivityStartTime_Time "ActivityStartTime/Time" true true false 8000 Text 0 0,First,#;ActivityStartTime_TimeZoneCode "ActivityStartTime/TimeZoneCode" true true false 8000 Text 0 0,First,#;MonitoringLocationIdentifier "MonitoringLocationIdentifier" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,MonitoringLocationIdentifier,0,8000;ResultIdentifier "ResultIdentifier" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ResultIdentifier,0,8000;DataLoggerLine "DataLoggerLine" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,DataLoggerLine,0,8000;ResultDetectionConditionText "ResultDetectionConditionText" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ResultDetectionConditionText,0,8000;MethodSpecificationName "MethodSpecificationName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,MethodSpecificationName,0,8000;CharacteristicName "CharacteristicName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,CharacteristicName,0,8000;ResultSampleFractionText "ResultSampleFractionText" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ResultSampleFractionText,0,8000;ResultMeasureValue "ResultMeasureValue" true true false 8 Double 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ResultMeasureValue,-1,-1;ResultMeasure_MeasureUnitCode "ResultMeasure/MeasureUnitCode" true true false 8000 Text 0 0,First,#;MeasureQualifierCode "MeasureQualifierCode" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,MeasureQualifierCode,0,8000;ResultStatusIdentifier "ResultStatusIdentifier" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ResultStatusIdentifier,0,8000;StatisticalBaseCode "StatisticalBaseCode" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,StatisticalBaseCode,0,8000;ResultValueTypeName "ResultValueTypeName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ResultValueTypeName,0,8000;ResultWeightBasisText "ResultWeightBasisText" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ResultWeightBasisText,0,8000;ResultTimeBasisText "ResultTimeBasisText" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ResultTimeBasisText,0,8000;ResultTemperatureBasisText "ResultTemperatureBasisText" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ResultTemperatureBasisText,0,8000;ResultParticleSizeBasisText "ResultParticleSizeBasisText" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ResultParticleSizeBasisText,0,8000;PrecisionValue "PrecisionValue" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,PrecisionValue,0,8000;DataQuality_BiasValue "DataQuality/BiasValue" true true false 8000 Text 0 0,First,#;ConfidenceIntervalValue "ConfidenceIntervalValue" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ConfidenceIntervalValue,0,8000;UpperConfidenceLimitValue "UpperConfidenceLimitValue" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,UpperConfidenceLimitValue,0,8000;LowerConfidenceLimitValue "LowerConfidenceLimitValue" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,LowerConfidenceLimitValue,0,8000;ResultCommentText "ResultCommentText" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ResultCommentText,0,8000;USGSPCode "USGSPCode" true true false 4 Long 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,USGSPCode,-1,-1;ResultDepthHeightMeasure_MeasureValue "ResultDepthHeightMeasure/MeasureValue" true true false 8000 Text 0 0,First,#;ResultDepthHeightMeasure_MeasureUnitCode "ResultDepthHeightMeasure/MeasureUnitCode" true true false 8000 Text 0 0,First,#;ResultDepthAltitudeReferencePointText "ResultDepthAltitudeReferencePointText" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ResultDepthAltitudeReferencePointText,0,8000;ResultSamplingPointName "ResultSamplingPointName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ResultSamplingPointName,0,8000;BiologicalIntentName "BiologicalIntentName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,BiologicalIntentName,0,8000;BiologicalIndividualIdentifier "BiologicalIndividualIdentifier" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,BiologicalIndividualIdentifier,0,8000;SubjectTaxonomicName "SubjectTaxonomicName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,SubjectTaxonomicName,0,8000;UnidentifiedSpeciesIdentifier "UnidentifiedSpeciesIdentifier" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,UnidentifiedSpeciesIdentifier,0,8000;SampleTissueAnatomyName "SampleTissueAnatomyName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,SampleTissueAnatomyName,0,8000;GroupSummaryCountWeight_MeasureValue "GroupSummaryCountWeight/MeasureValue" true true false 8000 Text 0 0,First,#;GroupSummaryCountWeight_MeasureUnitCode "GroupSummaryCountWeight/MeasureUnitCode" true true false 8000 Text 0 0,First,#;CellFormName "CellFormName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,CellFormName,0,8000;CellShapeName "CellShapeName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,CellShapeName,0,8000;HabitName "HabitName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,HabitName,0,8000;VoltismName "VoltismName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,VoltismName,0,8000;TaxonomicPollutionTolerance "TaxonomicPollutionTolerance" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,TaxonomicPollutionTolerance,0,8000;TaxonomicPollutionToleranceScaleText "TaxonomicPollutionToleranceScaleText" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,TaxonomicPollutionToleranceScaleText,0,8000;TrophicLevelName "TrophicLevelName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,TrophicLevelName,0,8000;FunctionalFeedingGroupName "FunctionalFeedingGroupName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,FunctionalFeedingGroupName,0,8000;TaxonomicDetailsCitation_ResourceTitleName "TaxonomicDetailsCitation/ResourceTitleName" true true false 8000 Text 0 0,First,#;TaxonomicDetailsCitation_ResourceCreatorName "TaxonomicDetailsCitation/ResourceCreatorName" true true false 8000 Text 0 0,First,#;TaxonomicDetailsCitation_ResourceSubjectText "TaxonomicDetailsCitation/ResourceSubjectText" true true false 8000 Text 0 0,First,#;TaxonomicDetailsCitation_ResourcePublisherName "TaxonomicDetailsCitation/ResourcePublisherName" true true false 8000 Text 0 0,First,#;TaxonomicDetailsCitation_ResourceDate "TaxonomicDetailsCitation/ResourceDate" true true false 8000 Text 0 0,First,#;TaxonomicDetailsCitation_ResourceIdentifier "TaxonomicDetailsCitation/ResourceIdentifier" true true false 8000 Text 0 0,First,#;FrequencyClassInformationUrl "FrequencyClassInformationUrl" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,FrequencyClassInformationUrl,0,8000;ResultAnalyticalMethod_MethodIdentifier "ResultAnalyticalMethod/MethodIdentifier" true true false 8000 Text 0 0,First,#;ResultAnalyticalMethod_MethodIdentifierContext "ResultAnalyticalMethod/MethodIdentifierContext" true true false 8000 Text 0 0,First,#;ResultAnalyticalMethod_MethodName "ResultAnalyticalMethod/MethodName" true true false 8000 Text 0 0,First,#;ResultAnalyticalMethod_MethodUrl "ResultAnalyticalMethod/MethodUrl" true true false 8000 Text 0 0,First,#;ResultAnalyticalMethod_MethodQualifierTypeName "ResultAnalyticalMethod/MethodQualifierTypeName" true true false 8000 Text 0 0,First,#;MethodDescriptionText "MethodDescriptionText" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,MethodDescriptionText,0,8000;LaboratoryName "LaboratoryName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,LaboratoryName,0,8000;AnalysisStartDate "AnalysisStartDate" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,AnalysisStartDate,0,8000;AnalysisStartTime_Time "AnalysisStartTime/Time" true true false 8000 Text 0 0,First,#;AnalysisStartTime_TimeZoneCode "AnalysisStartTime/TimeZoneCode" true true false 8000 Text 0 0,First,#;AnalysisEndDate "AnalysisEndDate" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,AnalysisEndDate,0,8000;AnalysisEndTime_Time "AnalysisEndTime/Time" true true false 8000 Text 0 0,First,#;AnalysisEndTime_TimeZoneCode "AnalysisEndTime/TimeZoneCode" true true false 8000 Text 0 0,First,#;ResultLaboratoryCommentCode "ResultLaboratoryCommentCode" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ResultLaboratoryCommentCode,0,8000;ResultLaboratoryCommentText "ResultLaboratoryCommentText" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ResultLaboratoryCommentText,0,8000;ResultDetectionQuantitationLimitUrl "ResultDetectionQuantitationLimitUrl" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ResultDetectionQuantitationLimitUrl,0,8000;LaboratoryAccreditationIndicator "LaboratoryAccreditationIndicator" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,LaboratoryAccreditationIndicator,0,8000;LaboratoryAccreditationAuthorityName "LaboratoryAccreditationAuthorityName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,LaboratoryAccreditationAuthorityName,0,8000;TaxonomistAccreditationIndicator "TaxonomistAccreditationIndicator" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,TaxonomistAccreditationIndicator,0,8000;TaxonomistAccreditationAuthorityName "TaxonomistAccreditationAuthorityName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,TaxonomistAccreditationAuthorityName,0,8000;LabSamplePreparationUrl "LabSamplePreparationUrl" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,LabSamplePreparationUrl,0,8000;ProviderName "ProviderName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ProviderName,0,8000;MonitoringLocationName "MonitoringLocationName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,MonitoringLocationName,0,8000;MonitoringLocationTypeName "MonitoringLocationTypeName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,MonitoringLocationTypeName,0,8000;ResolvedMonitoringLocationTypeName "ResolvedMonitoringLocationTypeName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,ResolvedMonitoringLocationTypeName,0,8000;HUCEightDigitCode "HUCEightDigitCode" true true false 4 Long 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,HUCEightDigitCode,-1,-1;siteUrl "siteUrl" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,siteUrl,0,8000;activityCount "activityCount" true true false 4 Long 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,activityCount,-1,-1;resultCount "resultCount" true true false 4 Long 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,resultCount,-1,-1;StateName "StateName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,StateName,0,8000;CountyName "CountyName" true true false 8000 Text 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,CountyName,0,8000;X "X" true true false 8 Double 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,X,-1,-1;Y "Y" true true false 8 Double 0 0,First,#,C:\temp\EPA-Water-Quality\working_20230501\csv\USGS-02376240.csv,Y,-1,-1',
    subtype="",
    expression="",
    match_fields=None,
    update_geometry="NOT_UPDATE_GEOMETRY"
)

# %%
arcpy.management.CreateTable(
    out_path=GDB_FULL_PATH,
    out_name="GoMA_Sample_Data",
    template=r"C:\temp\EPA-Water-Quality\csvSchema.csv",
    config_keyword="",
    out_alias=""
)
